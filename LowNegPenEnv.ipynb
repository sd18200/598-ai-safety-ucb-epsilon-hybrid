# %%
pip install gym numpy

# %%
import gym
from gym import spaces
import numpy as np
import matplotlib.pyplot as plt

class MazeEnvironment(gym.Env):
    def __init__(self, exploration_strategy='epsilon_greedy'):
        super(MazeEnvironment, self).__init__()

        self.action_space = spaces.Discrete(4)
        self.observation_space = spaces.Tuple((spaces.Discrete(5), spaces.Discrete(5)))

        self.initialize_maze()

        self.q_table = np.zeros((25, 4))  # 25 states and 4 actions
        self.epsilon = 1.0  # Initial exploration rate for epsilon-greedy
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.96
        self.alpha = 0.1  # Initial learning rate
        self.gamma = 0.90  # Discount factor
        self.last_episode_steps = np.inf  # Track steps of the last episode
        self.threshold_nse = 60  # Threshold for NSE mitigation
        self.nse_encounter_count = 0  # Counter for NSE encounters
        self.nse_encounters = []  # Track NSE encounters per episode
        self.exploration_strategy = exploration_strategy  # Exploration strategy: 'epsilon_greedy' or 'ucb'
        self.ucb_c = 1

    def initialize_maze(self):
        self.goal_state = (4, 4)
        self.start_state = (0, 0)
        self.agent_position = self.start_state
        self.forbidden_zones = {(1, 1), (1, 2)}
        self.blocked_paths = {(2, 2), (3, 2)}
        self.step_penalty_threshold = 10
        self.steps_taken = 0
        self.total_reward = 0

        self.maze = np.zeros((5, 5), dtype=str)
        for r in range(5):
            for c in range(5):
                self.maze[r, c] = '.'
        self.maze[self.goal_state] = 'G'
        for fz in self.forbidden_zones:
            self.maze[fz] = 'F'
        for bp in self.blocked_paths:
            self.maze[bp] = 'B'

    def reset(self):
        self.agent_position = self.start_state
        self.steps_taken = 0
        self.total_reward = 0
        self.update_maze_position(self.start_state, self.agent_position)
        return self.state_to_index(self.agent_position)

    def state_to_index(self, state):
        return state[0] * 5 + state[1]

    def step(self, action):
        if self.exploration_strategy == 'epsilon_greedy' and np.random.random() < self.epsilon:
            action = self.action_space.sample()

        next_state = list(self.agent_position)
        if action == 0 and next_state[0] > 0: next_state[0] -= 1
        elif action == 1 and next_state[0] < 4: next_state[0] += 1
        elif action == 2 and next_state[1] > 0: next_state[1] -= 1
        elif action == 3 and next_state[1] < 4: next_state[1] += 1

        next_state = tuple(next_state)
        reward, done = self.calculate_reward(next_state)
        self.total_reward += reward
        self.steps_taken += 1

        current_index = self.state_to_index(self.agent_position)
        next_index = self.state_to_index(next_state)
        best_future_reward = np.max(self.q_table[next_index])

        # Implement UCB exploration strategy
        if self.exploration_strategy == 'ucb':
            if np.sum(self.q_table[current_index]) > 0:
              exploration_bonus = self.ucb_c * np.sqrt(np.log(self.steps_taken + 1) / np.sum(self.q_table[current_index]))
            else:
              exploration_bonus = self.ucb_c * np.sqrt(np.log(self.steps_taken + 1) / 1e-6)

            ucb_q_values = self.q_table[current_index] + exploration_bonus
            action_ucb = np.argmax(ucb_q_values)

            if np.random.random() < self.epsilon:
                action = action_ucb

        self.q_table[current_index, action] += self.alpha * (reward + self.gamma * best_future_reward - self.q_table[current_index, action])

        self.update_maze_position(self.agent_position, next_state)
        self.agent_position = next_state

        if done:
            if self.exploration_strategy == 'epsilon_greedy':
                self.epsilon = max(self.epsilon * self.epsilon_decay, self.epsilon_min)
            elif self.exploration_strategy == 'ucb':
                # No need to update epsilon for UCB strategy
                pass

            if self.steps_taken > self.last_episode_steps:
                self.total_reward -= 10  # Penalty for more steps
            elif self.steps_taken < self.last_episode_steps:
                self.total_reward += 10  # Reward for fewer steps
            self.last_episode_steps = self.steps_taken  # Update last episode steps

            if self.total_reward < -self.threshold_nse:
                self.total_reward -= 25  # Additional penalty for exceeding NSE threshold

            self.nse_encounters.append(self.nse_encounter_count)
            self.nse_encounter_count = 0  # Reset NSE encounter count for next episode

        return self.state_to_index(next_state), reward, done, {}

    def calculate_reward(self, next_state):
        if next_state in self.forbidden_zones:
            self.nse_encounter_count += 1
            return -10, True
        elif next_state in self.blocked_paths:
            self.nse_encounter_count += 1
            return -5, False
        elif next_state == self.goal_state:
            return 100, True
        elif self.steps_taken % self.step_penalty_threshold == 0:
            self.nse_encounter_count += 0
            return -2, False
        return -1, False

    def update_maze_position(self, old_pos, new_pos):
        self.maze[old_pos] = '.'
        self.maze[new_pos] = 'A'

    def render(self, mode='human'):
        print("\n".join(["".join(row) for row in self.maze]))

class HybridMazeEnvironment(MazeEnvironment):
    def __init__(self):
        super(HybridMazeEnvironment, self).__init__()
        self.ucb_c = 1  # UCB exploration parameter
        # Initialize separate Q-tables for Epsilon-Greedy and UCB strategies
        self.q_table_greedy = np.zeros((25, 4))  # Q-table for epsilon-greedy
        self.q_table_ucb = np.zeros((25, 4))  # Q-table for UCB
        self.epsilon_greedy_epsilon = 1.0
        self.epsilon_greedy_decay = 0.96
        self.alpha=0.1
        self.gamma = 0.99


def step(self, action):
    current_index = self.state_to_index(self.agent_position)

    # Compute the next state based on the action taken
    next_state = list(self.agent_position)
    if action == 0 and next_state[0] > 0:
        next_state[0] -= 1
    elif action == 1 and next_state[0] < 4:
        next_state[0] += 1
    elif action == 2 and next_state[1] > 0:
        next_state[1] -= 1
    elif action == 3 and next_state[1] < 4:
        next_state[1] += 1

    next_state_tuple = tuple(next_state)

    # Perform action based on selected strategy
    if np.random.random() < self.epsilon_greedy_epsilon:
        strategy = 'epsilon_greedy'
    else:
        strategy = 'ucb'

    if strategy == 'epsilon_greedy':
        epsilon_action = np.argmax(self.q_table_greedy[current_index])
        next_state, reward, done, info = super().step(epsilon_action)
        self.update_q_table('greedy', current_index, epsilon_action, next_state_tuple, reward, done)
        self.epsilon_greedy_epsilon = max(self.epsilon_greedy_epsilon * self.epsilon_decay, self.epsilon_min)
    else:
        if np.sum(self.q_table[current_index]) > 0:
            exploration_bonus = self.ucb_c * np.sqrt(np.log(self.steps_taken + 1) / np.sum(self.q_table[current_index]))
        else:
            exploration_bonus = self.ucb_c * np.sqrt(np.log(self.steps_taken + 1) / 1e-6)

        ucb_q_values = self.q_table[current_index] + exploration_bonus
        ucb_action = np.argmax(ucb_q_values)
        next_state, reward, done, info = super().step(ucb_action)
        self.update_q_table('ucb', current_index, ucb_action, next_state_tuple, reward, done)

    return next_state_tuple, reward, done, info

def update_q_table(self, strategy, state_index, action, next_state, reward, done):
    # Update Q-table based on the strategy and other parameters
    next_index = self.state_to_index(next_state)
    best_future_reward = np.max(self.q_table[next_index])

    if strategy == 'greedy':
        self.q_table_greedy[state_index, action] += self.alpha * (
            reward + self.gamma * best_future_reward - self.q_table_greedy[state_index, action])
    elif strategy == 'ucb':
        self.q_table_ucb[state_index, action] += self.alpha * (
            reward + self.gamma * best_future_reward - self.q_table_ucb[state_index, action])

    self.update_maze_position(self.agent_position, next_state)
    self.agent_position = next_state

    if done:
        self.epsilon_greedy_epsilon = max(self.epsilon_greedy_epsilon * self.epsilon_decay, self.epsilon_min)
        if self.steps_taken > self.last_episode_steps:
            self.total_reward -= 10  # Penalty for more steps
        elif self.steps_taken < self.last_episode_steps:
            self.total_reward += 10  # Reward for fewer steps
        self.last_episode_steps = self.steps_taken  # Update last episode steps

        if self.total_reward < -self.threshold_nse:
            self.total_reward -= 50  # Additional penalty for exceeding NSE threshold

        self.nse_encounters.append(self.nse_encounter_count)
        self.nse_encounter_count = 0  # Reset NSE encounter count for next episode

    return self.state_to_index(next_state), reward, done, {}


if __name__ == "__main__":
    epsilon_greedy_env = MazeEnvironment(exploration_strategy='epsilon_greedy')
    ucb_env = MazeEnvironment(exploration_strategy='ucb')
    hybrid_env = HybridMazeEnvironment()
    episodes = 100
    rewards_epsilon_greedy = []
    steps_epsilon_greedy = []
    nse_encounters_epsilon_greedy = []
    rewards_ucb = []
    steps_ucb = []
    nse_encounters_ucb = []
    rewards_hybrid = []
    steps_hybrid = []
    nse_encounters_hybrid = []

    for e in range(episodes):
        # Run epsilon-greedy simulation
        state_epsilon_greedy = epsilon_greedy_env.reset()
        done_epsilon_greedy = False
        while not done_epsilon_greedy:
            action_epsilon_greedy = np.argmax(epsilon_greedy_env.q_table[epsilon_greedy_env.state_to_index(epsilon_greedy_env.agent_position)])
            state_epsilon_greedy, reward_epsilon_greedy, done_epsilon_greedy, info_epsilon_greedy = epsilon_greedy_env.step(action_epsilon_greedy)
        rewards_epsilon_greedy.append(epsilon_greedy_env.total_reward)
        steps_epsilon_greedy.append(epsilon_greedy_env.steps_taken)
        nse_encounters_epsilon_greedy.append(epsilon_greedy_env.nse_encounters[-1])

        # Run UCB simulation
        state_ucb = ucb_env.reset()
        done_ucb = False
        while not done_ucb:
            action_ucb = np.argmax(ucb_env.q_table[ucb_env.state_to_index(ucb_env.agent_position)])
            state_ucb, reward_ucb, done_ucb, info_ucb = ucb_env.step(action_ucb)
        rewards_ucb.append(ucb_env.total_reward)
        steps_ucb.append(ucb_env.steps_taken)
        nse_encounters_ucb.append(ucb_env.nse_encounters[-1])

        # Run Hybrid simulation
        state_hybrid = hybrid_env.reset()
        done_hybrid = False
        while not done_hybrid:
            action_hybrid = np.argmax(hybrid_env.q_table[hybrid_env.state_to_index(hybrid_env.agent_position)])
            state_hybrid, reward_hybrid, done_hybrid, info_hybrid = hybrid_env.step(action_hybrid)
        rewards_hybrid.append(hybrid_env.total_reward)
        steps_hybrid.append(hybrid_env.steps_taken)
        nse_encounters_hybrid.append(hybrid_env.nse_encounters[-1])

        print(f"Episode {e+1} (Epsilon-Greedy): Total Reward = {epsilon_greedy_env.total_reward}, Steps = {epsilon_greedy_env.steps_taken}")
        print(f"Episode {e+1} (UCB): Total Reward = {ucb_env.total_reward}, Steps = {ucb_env.steps_taken}")
        print(f"Episode {e+1} (Hybrid): Total Reward = {hybrid_env.total_reward}, Steps = {hybrid_env.steps_taken}")

    # Plotting the results
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(rewards_epsilon_greedy, label='Epsilon-Greedy')
    plt.plot(rewards_ucb, label='UCB')
    plt.plot(rewards_hybrid, label='Hybrid')
    plt.title('Total Rewards per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(steps_epsilon_greedy, label='Epsilon-Greedy')
    plt.plot(steps_ucb, label='UCB')
    plt.plot(steps_hybrid, label='Hybrid')
    plt.title('Steps per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Steps Taken')
    plt.legend()

    # Plot NSE encounters vs. episodes
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, episodes + 1), nse_encounters_epsilon_greedy, label='Epsilon-Greedy')
    plt.plot(range(1, episodes + 1), nse_encounters_ucb, label='UCB')
    plt.plot(range(1, episodes + 1), nse_encounters_hybrid, label='Hybrid')
    plt.title('Negative Penalties Encounters per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Negative Penalties Encounters')
    plt.legend()
    plt.show()
# Out:
# Episode 1 (Epsilon-Greedy): Total Reward = -18, Steps = 13
# Episode 1 (UCB): Total Reward = -7, Steps = 7
# Episode 1 (Hybrid): Total Reward = 88, Steps = 17
# Episode 2 (Epsilon-Greedy): Total Reward = -7, Steps = 7
# Episode 2 (UCB): Total Reward = -5, Steps = 5
# Episode 2 (Hybrid): Total Reward = -2, Steps = 2
# Episode 3 (Epsilon-Greedy): Total Reward = -6, Steps = 6
# Episode 3 (UCB): Total Reward = -27, Steps = 7
# Episode 3 (Hybrid): Total Reward = -25, Steps = 5
# Episode 4 (Epsilon-Greedy): Total Reward = -3, Steps = 3
# Episode 4 (UCB): Total Reward = -50, Steps = 28
# Episode 4 (Hybrid): Total Reward = -29, Steps = 9
# Episode 5 (Epsilon-Greedy): Total Reward = -27, Steps = 7
# Episode 5 (UCB): Total Reward = -7, Steps = 7
# Episode 5 (Hybrid): Total Reward = -7, Steps = 7
# Episode 6 (Epsilon-Greedy): Total Reward = -17, Steps = 7
# Episode 6 (UCB): Total Reward = -118, Steps = 60
# Episode 6 (Hybrid): Total Reward = -50, Steps = 28
# Episode 7 (Epsilon-Greedy): Total Reward = -3, Steps = 3
# Episode 7 (UCB): Total Reward = 10, Steps = 62
# Episode 7 (Hybrid): Total Reward = -4, Steps = 4
# Episode 8 (Epsilon-Greedy): Total Reward = -26, Steps = 6
# Episode 8 (UCB): Total Reward = -46, Steps = 113
# Episode 8 (Hybrid): Total Reward = -57, Steps = 34
# Episode 9 (Epsilon-Greedy): Total Reward = -51, Steps = 18
# Episode 9 (UCB): Total Reward = 79, Steps = 25
# Episode 9 (Hybrid): Total Reward = -5, Steps = 5
# Episode 10 (Epsilon-Greedy): Total Reward = -2, Steps = 2
# Episode 10 (UCB): Total Reward = 100, Steps = 10
# Episode 10 (Hybrid): Total Reward = -15, Steps = 5
# Episode 11 (Epsilon-Greedy): Total Reward = -154, Steps = 89
# Episode 11 (UCB): Total Reward = 64, Steps = 24
# Episode 11 (Hybrid): Total Reward = -39, Steps = 18
# Episode 12 (Epsilon-Greedy): Total Reward = -8, Steps = 8
# Episode 12 (UCB): Total Reward = 85, Steps = 23
# Episode 12 (Hybrid): Total Reward = -14, Steps = 13
# Episode 13 (Epsilon-Greedy): Total Reward = -4, Steps = 4
# Episode 13 (UCB): Total Reward = -4, Steps = 4
# Episode 13 (Hybrid): Total Reward = -125, Steps = 56
# Episode 14 (Epsilon-Greedy): Total Reward = -42, Steps = 21
# Episode 14 (UCB): Total Reward = -25, Steps = 5
# Episode 14 (Hybrid): Total Reward = -7, Steps = 7
# Episode 15 (Epsilon-Greedy): Total Reward = -2, Steps = 2
# Episode 15 (UCB): Total Reward = 70, Steps = 19
# Episode 15 (Hybrid): Total Reward = -29, Steps = 9
# Episode 16 (Epsilon-Greedy): Total Reward = -25, Steps = 5
# Episode 16 (UCB): Total Reward = 41, Steps = 45
# Episode 16 (Hybrid): Total Reward = -33, Steps = 12
# Episode 17 (Epsilon-Greedy): Total Reward = -31, Steps = 7
# Episode 17 (UCB): Total Reward = 89, Steps = 20
# Episode 17 (Hybrid): Total Reward = 53, Steps = 21
# Episode 18 (Epsilon-Greedy): Total Reward = -5, Steps = 5
# Episode 18 (UCB): Total Reward = 100, Steps = 10
# Episode 18 (Hybrid): Total Reward = -6, Steps = 6
# Episode 19 (Epsilon-Greedy): Total Reward = -3, Steps = 3
# Episode 19 (UCB): Total Reward = 79, Steps = 11
# Episode 19 (Hybrid): Total Reward = -33, Steps = 9
# Episode 20 (Epsilon-Greedy): Total Reward = -13, Steps = 3
# Episode 20 (UCB): Total Reward = -6, Steps = 6
# Episode 20 (Hybrid): Total Reward = 55, Steps = 32
# Episode 21 (Epsilon-Greedy): Total Reward = -26, Steps = 6
# Episode 21 (UCB): Total Reward = 77, Steps = 12
# Episode 21 (Hybrid): Total Reward = -10, Steps = 10
# Episode 22 (Epsilon-Greedy): Total Reward = -4, Steps = 4
# Episode 22 (UCB): Total Reward = 63, Steps = 25
# Episode 22 (Hybrid): Total Reward = -6, Steps = 6
# Episode 23 (Epsilon-Greedy): Total Reward = -2, Steps = 2
# Episode 23 (UCB): Total Reward = 85, Steps = 23
# Episode 23 (Hybrid): Total Reward = -3, Steps = 3
# Episode 24 (Epsilon-Greedy): Total Reward = -28, Steps = 8
# Episode 24 (UCB): Total Reward = 86, Steps = 22
# Episode 24 (Hybrid): Total Reward = 82, Steps = 8
# Episode 25 (Epsilon-Greedy): Total Reward = -2, Steps = 2
# Episode 25 (UCB): Total Reward = 91, Steps = 18
# Episode 25 (Hybrid): Total Reward = -53, Steps = 31
# Episode 26 (Epsilon-Greedy): Total Reward = -35, Steps = 14
# Episode 26 (UCB): Total Reward = 89, Steps = 16
# Episode 26 (Hybrid): Total Reward = 93, Steps = 16
# Episode 27 (Epsilon-Greedy): Total Reward = 23, Steps = 40
# Episode 27 (UCB): Total Reward = -6, Steps = 6
# Episode 27 (Hybrid): Total Reward = 100, Steps = 10
# Episode 28 (Epsilon-Greedy): Total Reward = 39, Steps = 43
# Episode 28 (UCB): Total Reward = 79, Steps = 11
# Episode 28 (Hybrid): Total Reward = 69, Steps = 20
# Episode 29 (Epsilon-Greedy): Total Reward = 97, Steps = 12
# Episode 29 (UCB): Total Reward = 77, Steps = 12
# Episode 29 (Hybrid): Total Reward = -2, Steps = 2
# Episode 30 (Epsilon-Greedy): Total Reward = 65, Steps = 23
# Episode 30 (UCB): Total Reward = 87, Steps = 12
# Episode 30 (Hybrid): Total Reward = 70, Steps = 19
# Episode 31 (Epsilon-Greedy): Total Reward = 55, Steps = 32
# Episode 31 (UCB): Total Reward = 74, Steps = 15
# Episode 31 (Hybrid): Total Reward = 96, Steps = 10
# Episode 32 (Epsilon-Greedy): Total Reward = -3, Steps = 3
# Episode 32 (UCB): Total Reward = -4, Steps = 4
# Episode 32 (Hybrid): Total Reward = -9, Steps = 9
# Episode 33 (Epsilon-Greedy): Total Reward = -24, Steps = 4
# Episode 33 (UCB): Total Reward = 80, Steps = 10
# Episode 33 (Hybrid): Total Reward = 70, Steps = 19
# Episode 34 (Epsilon-Greedy): Total Reward = 55, Steps = 32
# Episode 34 (UCB): Total Reward = 74, Steps = 15
# Episode 34 (Hybrid): Total Reward = 87, Steps = 18
# Episode 35 (Epsilon-Greedy): Total Reward = 91, Steps = 18
# Episode 35 (UCB): Total Reward = 99, Steps = 11
# Episode 35 (Hybrid): Total Reward = 92, Steps = 17
# Episode 36 (Epsilon-Greedy): Total Reward = 97, Steps = 12
# Episode 36 (UCB): Total Reward = 101, Steps = 9
# Episode 36 (Hybrid): Total Reward = 65, Steps = 23
# Episode 37 (Epsilon-Greedy): Total Reward = 66, Steps = 22
# Episode 37 (UCB): Total Reward = 79, Steps = 11
# Episode 37 (Hybrid): Total Reward = -7, Steps = 7
# Episode 38 (Epsilon-Greedy): Total Reward = 92, Steps = 17
# Episode 38 (UCB): Total Reward = -2, Steps = 2
# Episode 38 (Hybrid): Total Reward = -2, Steps = 2
# Episode 39 (Epsilon-Greedy): Total Reward = 59, Steps = 29
# Episode 39 (UCB): Total Reward = 75, Steps = 14
# Episode 39 (Hybrid): Total Reward = 77, Steps = 12
# Episode 40 (Epsilon-Greedy): Total Reward = 53, Steps = 31
# Episode 40 (UCB): Total Reward = 100, Steps = 10
# Episode 40 (Hybrid): Total Reward = 65, Steps = 23
# Episode 41 (Epsilon-Greedy): Total Reward = 84, Steps = 24
# Episode 41 (UCB): Total Reward = 90, Steps = 10
# Episode 41 (Hybrid): Total Reward = 93, Steps = 16
# Episode 42 (Epsilon-Greedy): Total Reward = 97, Steps = 12
# Episode 42 (UCB): Total Reward = 101, Steps = 9
# Episode 42 (Hybrid): Total Reward = 83, Steps = 16
# Episode 43 (Epsilon-Greedy): Total Reward = 64, Steps = 24
# Episode 43 (UCB): Total Reward = 79, Steps = 11
# Episode 43 (Hybrid): Total Reward = -3, Steps = 3
# Episode 44 (Epsilon-Greedy): Total Reward = 99, Steps = 11
# Episode 44 (UCB): Total Reward = 75, Steps = 14
# Episode 44 (Hybrid): Total Reward = 76, Steps = 13
# Episode 45 (Epsilon-Greedy): Total Reward = 100, Steps = 10
# Episode 45 (UCB): Total Reward = 100, Steps = 10
# Episode 45 (Hybrid): Total Reward = 99, Steps = 11
# Episode 46 (Epsilon-Greedy): Total Reward = -34, Steps = 13
# Episode 46 (UCB): Total Reward = 102, Steps = 8
# Episode 46 (Hybrid): Total Reward = 101, Steps = 9
# Episode 47 (Epsilon-Greedy): Total Reward = 101, Steps = 9
# Episode 47 (UCB): Total Reward = 80, Steps = 10
# Episode 47 (Hybrid): Total Reward = 66, Steps = 22
# Episode 48 (Epsilon-Greedy): Total Reward = 77, Steps = 12
# Episode 48 (UCB): Total Reward = 101, Steps = 9
# Episode 48 (Hybrid): Total Reward = 101, Steps = 9
# Episode 49 (Epsilon-Greedy): Total Reward = 75, Steps = 14
# Episode 49 (UCB): Total Reward = 91, Steps = 9
# Episode 49 (Hybrid): Total Reward = 77, Steps = 12
# Episode 50 (Epsilon-Greedy): Total Reward = 85, Steps = 14
# Episode 50 (UCB): Total Reward = 91, Steps = 9
# Episode 50 (Hybrid): Total Reward = 101, Steps = 9
# Episode 51 (Epsilon-Greedy): Total Reward = 66, Steps = 22
# Episode 51 (UCB): Total Reward = 80, Steps = 10
# Episode 51 (Hybrid): Total Reward = 91, Steps = 9
# Episode 52 (Epsilon-Greedy): Total Reward = -4, Steps = 4
# Episode 52 (UCB): Total Reward = 102, Steps = 8
# Episode 52 (Hybrid): Total Reward = 69, Steps = 20
# Episode 53 (Epsilon-Greedy): Total Reward = 63, Steps = 25
# Episode 53 (UCB): Total Reward = 81, Steps = 9
# Episode 53 (Hybrid): Total Reward = 97, Steps = 12
# Episode 54 (Epsilon-Greedy): Total Reward = 102, Steps = 8
# Episode 54 (UCB): Total Reward = 91, Steps = 9
# Episode 54 (Hybrid): Total Reward = 74, Steps = 15
# Episode 55 (Epsilon-Greedy): Total Reward = 79, Steps = 11
# Episode 55 (UCB): Total Reward = 91, Steps = 9
# Episode 55 (Hybrid): Total Reward = 100, Steps = 10
# Episode 56 (Epsilon-Greedy): Total Reward = 101, Steps = 9
# Episode 56 (UCB): Total Reward = 91, Steps = 9
# Episode 56 (Hybrid): Total Reward = 75, Steps = 14
# Episode 57 (Epsilon-Greedy): Total Reward = 75, Steps = 14
# Episode 57 (UCB): Total Reward = 102, Steps = 8
# Episode 57 (Hybrid): Total Reward = 99, Steps = 11
# Episode 58 (Epsilon-Greedy): Total Reward = 97, Steps = 12
# Episode 58 (UCB): Total Reward = 92, Steps = 8
# Episode 58 (Hybrid): Total Reward = 75, Steps = 14
# Episode 59 (Epsilon-Greedy): Total Reward = 76, Steps = 13
# Episode 59 (UCB): Total Reward = 92, Steps = 8
# Episode 59 (Hybrid): Total Reward = 102, Steps = 8
# Episode 60 (Epsilon-Greedy): Total Reward = 100, Steps = 10
# Episode 60 (UCB): Total Reward = 81, Steps = 9
# Episode 60 (Hybrid): Total Reward = 81, Steps = 9
# Episode 61 (Epsilon-Greedy): Total Reward = 101, Steps = 9
# Episode 61 (UCB): Total Reward = 102, Steps = 8
# Episode 61 (Hybrid): Total Reward = 76, Steps = 13
# Episode 62 (Epsilon-Greedy): Total Reward = 62, Steps = 26
# Episode 62 (UCB): Total Reward = 92, Steps = 8
# Episode 62 (Hybrid): Total Reward = 100, Steps = 10
# Episode 63 (Epsilon-Greedy): Total Reward = -2, Steps = 2
# Episode 63 (UCB): Total Reward = 92, Steps = 8
# Episode 63 (Hybrid): Total Reward = 101, Steps = 9
# Episode 64 (Epsilon-Greedy): Total Reward = 81, Steps = 9
# Episode 64 (UCB): Total Reward = 81, Steps = 9
# Episode 64 (Hybrid): Total Reward = 102, Steps = 8
# Episode 65 (Epsilon-Greedy): Total Reward = -2, Steps = 2
# Episode 65 (UCB): Total Reward = 102, Steps = 8
# Episode 65 (Hybrid): Total Reward = 77, Steps = 12
# Episode 66 (Epsilon-Greedy): Total Reward = 80, Steps = 10
# Episode 66 (UCB): Total Reward = 92, Steps = 8
# Episode 66 (Hybrid): Total Reward = 102, Steps = 8
# Episode 67 (Epsilon-Greedy): Total Reward = 101, Steps = 9
# Episode 67 (UCB): Total Reward = 92, Steps = 8
# Episode 67 (Hybrid): Total Reward = 92, Steps = 8
# Episode 68 (Epsilon-Greedy): Total Reward = -4, Steps = 4
# Episode 68 (UCB): Total Reward = 92, Steps = 8
# Episode 68 (Hybrid): Total Reward = 81, Steps = 9
# Episode 69 (Epsilon-Greedy): Total Reward = 82, Steps = 8
# Episode 69 (UCB): Total Reward = 92, Steps = 8
# Episode 69 (Hybrid): Total Reward = 102, Steps = 8
# Episode 70 (Epsilon-Greedy): Total Reward = 81, Steps = 9
# Episode 70 (UCB): Total Reward = 92, Steps = 8
# Episode 70 (Hybrid): Total Reward = 80, Steps = 10
# Episode 71 (Epsilon-Greedy): Total Reward = 91, Steps = 9
# Episode 71 (UCB): Total Reward = 92, Steps = 8
# Episode 71 (Hybrid): Total Reward = 86, Steps = 10
# Episode 72 (Epsilon-Greedy): Total Reward = 102, Steps = 8
# Episode 72 (UCB): Total Reward = 92, Steps = 8
# Episode 72 (Hybrid): Total Reward = 102, Steps = 8
# Episode 73 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 73 (UCB): Total Reward = 92, Steps = 8
# Episode 73 (Hybrid): Total Reward = 81, Steps = 9
# Episode 74 (Epsilon-Greedy): Total Reward = 81, Steps = 9
# Episode 74 (UCB): Total Reward = 92, Steps = 8
# Episode 74 (Hybrid): Total Reward = 102, Steps = 8
# Episode 75 (Epsilon-Greedy): Total Reward = 102, Steps = 8
# Episode 75 (UCB): Total Reward = 92, Steps = 8
# Episode 75 (Hybrid): Total Reward = 92, Steps = 8
# Episode 76 (Epsilon-Greedy): Total Reward = 72, Steps = 13
# Episode 76 (UCB): Total Reward = 92, Steps = 8
# Episode 76 (Hybrid): Total Reward = 92, Steps = 8
# Episode 77 (Epsilon-Greedy): Total Reward = 100, Steps = 10
# Episode 77 (UCB): Total Reward = 92, Steps = 8
# Episode 77 (Hybrid): Total Reward = 92, Steps = 8
# Episode 78 (Epsilon-Greedy): Total Reward = 102, Steps = 8
# Episode 78 (UCB): Total Reward = 92, Steps = 8
# Episode 78 (Hybrid): Total Reward = 92, Steps = 8
# Episode 79 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 79 (UCB): Total Reward = 92, Steps = 8
# Episode 79 (Hybrid): Total Reward = 80, Steps = 10
# Episode 80 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 80 (UCB): Total Reward = 92, Steps = 8
# Episode 80 (Hybrid): Total Reward = 102, Steps = 8
# Episode 81 (Epsilon-Greedy): Total Reward = 80, Steps = 10
# Episode 81 (UCB): Total Reward = 92, Steps = 8
# Episode 81 (Hybrid): Total Reward = 92, Steps = 8
# Episode 82 (Epsilon-Greedy): Total Reward = 102, Steps = 8
# Episode 82 (UCB): Total Reward = 92, Steps = 8
# Episode 82 (Hybrid): Total Reward = 81, Steps = 9
# Episode 83 (Epsilon-Greedy): Total Reward = 88, Steps = 8
# Episode 83 (UCB): Total Reward = 92, Steps = 8
# Episode 83 (Hybrid): Total Reward = 91, Steps = 9
# Episode 84 (Epsilon-Greedy): Total Reward = 76, Steps = 10
# Episode 84 (UCB): Total Reward = 92, Steps = 8
# Episode 84 (Hybrid): Total Reward = 80, Steps = 10
# Episode 85 (Epsilon-Greedy): Total Reward = 102, Steps = 8
# Episode 85 (UCB): Total Reward = 92, Steps = 8
# Episode 85 (Hybrid): Total Reward = 102, Steps = 8
# Episode 86 (Epsilon-Greedy): Total Reward = 68, Steps = 17
# Episode 86 (UCB): Total Reward = 92, Steps = 8
# Episode 86 (Hybrid): Total Reward = 92, Steps = 8
# Episode 87 (Epsilon-Greedy): Total Reward = 102, Steps = 8
# Episode 87 (UCB): Total Reward = 92, Steps = 8
# Episode 87 (Hybrid): Total Reward = 92, Steps = 8
# Episode 88 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 88 (UCB): Total Reward = 92, Steps = 8
# Episode 88 (Hybrid): Total Reward = 92, Steps = 8
# Episode 89 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 89 (UCB): Total Reward = 92, Steps = 8
# Episode 89 (Hybrid): Total Reward = 92, Steps = 8
# Episode 90 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 90 (UCB): Total Reward = 92, Steps = 8
# Episode 90 (Hybrid): Total Reward = 81, Steps = 9
# Episode 91 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 91 (UCB): Total Reward = 92, Steps = 8
# Episode 91 (Hybrid): Total Reward = 102, Steps = 8
# Episode 92 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 92 (UCB): Total Reward = 92, Steps = 8
# Episode 92 (Hybrid): Total Reward = 92, Steps = 8
# Episode 93 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 93 (UCB): Total Reward = 92, Steps = 8
# Episode 93 (Hybrid): Total Reward = 92, Steps = 8
# Episode 94 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 94 (UCB): Total Reward = 92, Steps = 8
# Episode 94 (Hybrid): Total Reward = 92, Steps = 8
# Episode 95 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 95 (UCB): Total Reward = 92, Steps = 8
# Episode 95 (Hybrid): Total Reward = 92, Steps = 8
# Episode 96 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 96 (UCB): Total Reward = 92, Steps = 8
# Episode 96 (Hybrid): Total Reward = 92, Steps = 8
# Episode 97 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 97 (UCB): Total Reward = 92, Steps = 8
# Episode 97 (Hybrid): Total Reward = 92, Steps = 8
# Episode 98 (Epsilon-Greedy): Total Reward = 80, Steps = 10
# Episode 98 (UCB): Total Reward = 92, Steps = 8
# Episode 98 (Hybrid): Total Reward = 92, Steps = 8
# Episode 99 (Epsilon-Greedy): Total Reward = 102, Steps = 8
# Episode 99 (UCB): Total Reward = 92, Steps = 8
# Episode 99 (Hybrid): Total Reward = 92, Steps = 8
# Episode 100 (Epsilon-Greedy): Total Reward = 92, Steps = 8
# Episode 100 (UCB): Total Reward = 92, Steps = 8
# Episode 100 (Hybrid): Total Reward = 92, Steps = 8
